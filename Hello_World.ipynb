# %%
hw_string = 'HELLO WORLD'
hw_list = []
hw_list = hw_string
for i, char in enumerate(hw_list):
    pad = (i+1)*5
    print(f'{char: >{pad}}')
# Out:
#     H
#          E
#               L
#                    L
#                         O
#
#                                   W
#                                        O
#                                             R
#                                                  L
#                                                       D
